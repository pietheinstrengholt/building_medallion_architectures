# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
import sempy.fabric as fabric
import pandas as pd

fabricClient = fabric.FabricRestClient()

urlWorkspace = "v1/workspaces"
workspaceId = "30950d63-22f3-4d65-8813-310477df47b4"
finalReqUrl = urlWorkspace + "/"+ workspaceId + "/items"
result = fabricClient.get(finalReqUrl)

df_items = pd.json_normalize(result.json()['value'])

display(df_items)
# Out:
# StatementMeta(, 80ebcb9f-42e2-4f30-91dd-3201aff67984, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, c98c7fd0-99ec-4277-ac37-5a155f026891)
